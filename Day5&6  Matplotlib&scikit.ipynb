# %% [markdown]
# ## matplotlib is a python library for visualizastion part

# %% [markdown]
# - lineplot
# - scatterplot
# - barplot
# - piechart
# - boxplot
# - histogram

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## r-- is used to change the color of line(r=red,g=green)

# %% [markdown]
# ## * is used to mark the matched point with star

# %%
x=[1.1,1.2,2.1,2.2]
y=[8.8,8.2,8.7,7.9]
plt.plot(x,y,'r*--')
plt.show()

# %%
x=[1.1,1.2,2.1,2.2,3.1]
y=[8.8,8.2,8.7,7.9,9.2]
plt.plot(x,y,'m*--')
plt.show()

# %% [markdown]
# ## ^ for traingle marks

# %%
plt.plot(x,y,"^")

# %% [markdown]
# ## go is used for circle marks

# %%
plt.plot(x,y,"go")

# %% [markdown]
# ## grid view

# %%
plt.plot(x,y,"go")
plt.plot(y,x,"c*")## c* is a skycolor star
plt.grid()
plt.show()

# %%
plt.plot(x,y,"go",label="xyvalues")
plt.plot(y,x,"c*",label="yxvalues")## c* is a skycolor star
plt.legend()
plt.grid()
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.plot(x,y,"go",label="xyvalues")
plt.plot(y,x,"c*",label="yxvalues")## c* is a skycolor star
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.plot(x,y,"go",label="xyvalues")
plt.plot(y,x,"c*",label="yxvalues")## c* is a skycolor star
plt.legend(loc="lower right")
plt.grid()
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
x=[1,3,4,5]
y=[3,4,5,6]
plt.scatter(x,x,color="red")
plt.scatter(x,y,color='g')
plt.grid()

# %%
import numpy as np

# %%
x=np.linspace(5,20,20)

# %%
plt.plot(x,x**2,color='r')
plt.plot(x,x,color="g")

# %%
x=np.arange(1,19)
z=x[x%2!=0]
y=x[x%2==0]
plt.plot(y,y,'r*',label="even numbers")
plt.plot(z,z,'go',label="odd numbers")
plt.legend()

# %% [markdown]
# ## Bargraph

# %%
x=[60,70,40,80,30,50]
y=[50,40,60,90,60,30]
plt.grid()
plt.bar(x,y,color='y',label="Marks")# k=black,r=red,sb=skyblue
plt.legend(loc="upper right")

# %% [markdown]
# ## bar is for vertical graph

# %%
x=[60,70,40,80,30,50]
y=[50,40,60,90,60,30]
plt.grid()
plt.bar(x,y,color='y',width=5,label="Marks")# k=black,r=red,sb=skyblue
plt.legend()

# %% [markdown]
# ## barh is for horizontal graph

# %%
plt.barh(x,y,color='y',height=5)
# Out:
# <BarContainer object of 6 artists>

# %%
x=["mani","anil","raj","abhi","raghu"]
y=[84,55,37,66,57]
plt.bar(x,y,color="g",label="Marks")
plt.legend()
plt.title("Python Marks")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
plt.savefig("pythonmarks.jpg")

# %%
x=["mani","anil","raj","abhi","raghu"]
y=[84,55,37,66,57]
plt.barh(x,y,color="g",label="Marks")
plt.legend()
plt.title("Python Marks")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
plt.savefig("pythonmarks.jpg")

# %% [markdown]
# ## Histogram

# %%
x=np.array([1,3,4,5,6,0])
plt.hist(x,bins=5)
# Out:
# (array([2., 0., 1., 1., 2.]),
#  array([0. , 1.2, 2.4, 3.6, 4.8, 6. ]),
#  <BarContainer object of 5 artists>)

# %%
y=np.random.randint(1,100,5)
plt.hist(y,bins=10)
# Out:
# (array([1., 0., 1., 1., 0., 0., 0., 0., 0., 2.]),
#  array([15. , 23.1, 31.2, 39.3, 47.4, 55.5, 63.6, 71.7, 79.8, 87.9, 96. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ##  Pie graphs

# %%
x=["cse","it","ece","eee"]
y=[240,60,240,60]
plt.pie(y,labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x19ae016d490>,
# ...
#  [Text(0.33991867422268784, 1.0461621742897658, 'cse'),
#   Text(-1.0461621822461362, 0.3399186497354952, 'it'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'ece'),
#   Text(1.0461621981588753, -0.33991860076110864, 'eee')])

# %%
plt.pie(y,labels=x,explode=[0.2,0.2,0,0])# 0.2 is distance  to seperate the pie graph
# Out:
# ([<matplotlib.patches.Wedge at 0x19ae12ab2b0>,
# ...
#  [Text(0.40172206953590384, 1.2363734787060867, 'cse'),
#   Text(-1.23637348810907, 0.4017220405964943, 'it'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'ece'),
#   Text(1.0461621981588753, -0.33991860076110864, 'eee')])

# %%
plt.pie(y,labels=x,explode=[2,0.2,0,0.5])
# Out:
# ([<matplotlib.patches.Wedge at 0x19adf586cd0>,
# ...
#  [Text(0.9579526273548475, 2.9482752184529764, 'cse'),
#   Text(-1.23637348810907, 0.4017220405964943, 'it'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'ece'),
#   Text(1.5216904700492733, -0.49442705565252165, 'eee')])

# %%
plt.pie(y,labels=x,explode=[0.5,0.5,0.5,0.5])
# Out:
# ([<matplotlib.patches.Wedge at 0x19adfc94130>,
# ...
#  [Text(0.49442716250572777, 1.5216904353305685, 'cse'),
#   Text(-1.5216904469034709, 0.49442712688799295, 'it'),
#   Text(-0.4944270912702571, -1.5216904584763726, 'ece'),
#   Text(1.5216904700492733, -0.49442705565252165, 'eee')])

# %% [markdown]
# ## box plot

# %%
x=[60,50,40,30]# yellow line is median
plt.boxplot(x)# low line is minimum and high line is maximum
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ae005c070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ae005c370>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ae00fe4f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19ae005c430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19adfed2b20>],
#  'means': []}

# %%
x=[60,50,40,30]
y=[24,60,27,6]
z=[44,50,66,99]
data=[x,y,z]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ae15a23d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ae15a2a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ae15a2070>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x19ae15af190>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x19ae15af4f0>,
# ...
#  'means': []}

# %%
import pandas as pd

# %%
d=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv")

# %%
d
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
d.replace(np.nan,5,inplace=True)
d
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
d.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# cabin       0
# embarked    0
# dtype: int64

# %%
t=d.head()
t
l=t["pclass"]

# %%
plt.boxplot(d["pclass"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ae22d2250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ae22d2910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ae22c4eb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19ae22d2fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19ae22dd370>],
#  'means': []}

# %%
plt.boxplot(d["fare"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ae240fc10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ae241f310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ae240f8b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19ae241f9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19ae241fd30>],
#  'means': []}

# %%
plt.boxplot(l)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ae24c1a00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ae24cf100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ae24c16a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19ae24cf7c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19ae24cfb20>],
#  'means': []}

# %%
d.survived.value_counts().plot(kind='bar',alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
d.pclass.value_counts().plot(kind='bar',alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
d.embarked.value_counts().plot(kind='bar',alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
d.survived.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
d.survived.value_counts().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
t
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500     5        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250     5        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500     5        S

# %%
t.sibsp.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
d=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv")

# %%
d.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
d.age.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
d.age.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='age'>

# %% [markdown]
# ## subplots

# %%
import matplotlib.pyplot as plt

# %%
plt.subplots(2,5)## 2rows and 5 columns
plt.show()

# %%
import numpy as np
x=np.array([20,40,58,70,60])
y=np.array([30,35,55,80,50])
plt.subplot(2,2,1)
plt.plot(x,y,'r*',label="firstrow firstcolumn")
plt.legend()
plt.subplot(2,2,2)
plt.plot(x,y,'g^',label="firstrow secondcolumn")
plt.legend()
plt.subplot(2,2,3)
plt.plot(x,y,'c+',label="secondrow firstcolumn")
plt.legend()
plt.subplot(2,2,4)
plt.plot(x,y,'k--',label="secondrow secondcolumn")
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
d=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv")

# %%
d
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
d.survived.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
t=d.survived.value_counts()
t
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
plt.subplot(1,2,1)
plt.plot(t,"r")
plt.subplot(1,2,1)
plt.plot(t,"g")
plt.show()
# Out:
# <ipython-input-42-adcadf6e1ecb>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1,2,1)

# %%
d.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
d.drop("name",axis=1,inplace=True)

# %%
d.drop("sex",axis=1,inplace=True)

# %%
d.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# embarked      2
# dtype: int64

# %%
d.drop("cabin",axis=1,inplace=True)#1=column,0=row

# %%
d["age"].fillna(d["age"].mean(),inplace=True)

# %%
d.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    2
# dtype: int64

# %%
d["embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
d[d["embarked"]=='S'].value_counts().sum()
# Out:
# 644

# %%
d[d["embarked"]=='C'].value_counts().sum()
# Out:
# 168

# %%
d["embarked"].fillna("S",inplace=True)

# %%
d.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       891 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   fare      891 non-null    float64
#  8   embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
pd.get_dumies(d["embarked"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-cf59eeaf5ba2> in <module>
# ----> 1 pd.getdumies(d["embarked"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'getdumies'

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
d["embarked"]=le.fit_transform(d["embarked"])

# %%
d["embarked"]
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: embarked, Length: 891, dtype: int64

# %%
d["embarked"].unique()
# Out:
# array([2, 0, 1])

# %%
    d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       891 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   embarked  891 non-null    int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
d["sex"]=le.fit_transform(d["sex"])
d["sex"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: sex, Length: 891, dtype: int32

# %%
d["sex"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ## Scalling Techniques
# ### 1.MinMax scaler
# ### 2.Robust scaler
# ### 3.Standalization
# ### 4.Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %% [markdown]
# ## on string values we cant  do minmax so we need to drop the string value columns

# %%
'''xi-Min(x)
-------------
min(x)-max(x)
'''
df2=minmax.fit_transform(d)
df2
# Out:
# array([[0.        , 1.        , 0.27117366, ..., 0.        , 0.01415106,
#         1.        ],
#        [1.        , 0.        , 0.4722292 , ..., 0.        , 0.13913574,
#         0.        ],
#        [1.        , 1.        , 0.32143755, ..., 0.        , 0.01546857,
#         1.        ],
#        ...,
#        [0.        , 1.        , 0.36792055, ..., 0.33333333, 0.04577135,
#         1.        ],
#        [1.        , 0.        , 0.32143755, ..., 0.        , 0.0585561 ,
#         0.        ],
#        [0.        , 1.        , 0.39683338, ..., 0.        , 0.01512699,
#         0.5       ]])

# %%
d.columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'embarked'], dtype='object')

# %%
df3=pd.DataFrame(df2,columns=d.columns)

# %%
df4=minmax.fit_transform([d["survived"],d["pclass"]])

# %%
d
# Out:
# array([[0.        , 1.        , 1.        , ..., 0.        , 0.07287449,
#         1.        ],
#        [1.        , 0.        , 0.        , ..., 0.        , 0.83805668,
#         0.        ],
#        [1.        , 1.        , 0.        , ..., 0.        , 0.1659919 ,
#         1.        ],
#        ...,
#        [0.        , 1.        , 0.        , ..., 0.33333333, 0.53036437,
#         1.        ],
#        [1.        , 0.        , 1.        , ..., 0.        , 0.6194332 ,
#         0.        ],
#        [0.        , 1.        , 1.        , ..., 0.        , 0.12145749,
#         0.5       ]])

# %%
d.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')

# %% [markdown]
# ## Robust scaler
# - it is mainly uses in datasets in outliers
# - Scaling between 25% and 75%
# - Xi-Q2(X)
# ------------
# - Q1(X)-Q3(X)
# - inner Quartile
# - 25% lower Quartile
# - 50% medium Quartile
# - 75% upper Quartile

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs=RobustScaler()

# %%
df2=rs.fit_transform(d)

# %%
df3=pd.DataFrame(df2,columns=d.columns)
df3
# Out:
#      survived  pclass       age  sibsp  parch      fare  embarked
# 0         0.0     0.0 -0.592240    1.0    0.0 -0.312011       0.0
# 1         1.0    -2.0  0.638529    1.0    0.0  2.461242      -2.0
# 2         1.0     0.0 -0.284548    0.0    0.0 -0.282777       0.0
# 3         1.0    -2.0  0.407760    1.0    0.0  1.673732       0.0
# 4         0.0     0.0  0.407760    0.0    0.0 -0.277363       0.0
# ..        ...     ...       ...    ...    ...       ...       ...
# 886       0.0    -1.0 -0.207624    0.0    0.0 -0.062981       0.0
# 887       1.0    -2.0 -0.823009    0.0    0.0  0.673281       0.0
# 888       0.0     0.0  0.000000    1.0    2.0  0.389604       0.0
# 889       1.0    -2.0 -0.284548    0.0    0.0  0.673281      -2.0
# 890       0.0     0.0  0.176991    0.0    0.0 -0.290356      -1.0
#
# [891 rows x 7 columns]

# %%
from sklearn.preprocessing import Normalizer

# %%
nr=Normalizer()

# %%
df2=nr.fit_transform(d)

# %%
df3=pd.DataFrame(df2,columns=d.columns)
df3
# Out:
#      survived    pclass       age     sibsp     parch      fare  embarked
# 0    0.000000  0.127855  0.937604  0.042618  0.000000  0.308983  0.085237
# 1    0.012377  0.012377  0.470309  0.012377  0.000000  0.882241  0.000000
# 2    0.036447  0.109340  0.947615  0.000000  0.000000  0.288840  0.072893
# 3    0.015710  0.015710  0.549863  0.015710  0.000000  0.834220  0.031421
# 4    0.000000  0.083115  0.969681  0.000000  0.000000  0.223027  0.055410
# ..        ...       ...       ...       ...       ...       ...       ...
# 886  0.000000  0.066446  0.897015  0.000000  0.000000  0.431896  0.066446
# 887  0.028094  0.028094  0.533784  0.000000  0.000000  0.842816  0.056188
# 888  0.000000  0.078785  0.779953  0.026262  0.052524  0.615840  0.052524
# 889  0.025174  0.025174  0.654515  0.000000  0.000000  0.755210  0.000000
# 890  0.000000  0.090699  0.967451  0.000000  0.000000  0.234305  0.030233
#
# [891 rows x 7 columns]

# %% [markdown]
# ## Seaborn
# - Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# - Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
# - matplotlib
# - seaborn
# - Bokeh
# ## visualization tools
# - tables
# - SAS
# - Power Blue

# %% [markdown]
# ## Seaborn Styles
# - catagorical scatter plot
#    - strip plot
#    - swarn plot
# - catagorical distribution plots
#    - box plot
#    - voilin plot
# - catagorical Estimate plots
#    - count plot
#    - point plot
#    - bar plot

# %%
#pip install seaborn

# %%
import seaborn as sns

# %%
#dir(sns)

# %% [markdown]
# ## seaborn styles
# - white
# - dark
# - whitegrid
# - darkgrid
# - ticks

# %%
sns.set_style("ticks")# white,dark,whitegrid,darkgrid,ticks

# %% [markdown]
# ## inbuilt datasets present in  seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.groupby("species").count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.color_palette()# default colors in sns
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette(n_colors=5)
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353)]

# %%
sns.color_palette('Accent')
# Out:
# [(0.4980392156862745, 0.788235294117647, 0.4980392156862745),
#  (0.7450980392156863, 0.6823529411764706, 0.8313725490196079),
#  (0.9921568627450981, 0.7529411764705882, 0.5254901960784314),
#  (1.0, 1.0, 0.6),
#  (0.2196078431372549, 0.4235294117647059, 0.6901960784313725),
#  (0.9411764705882353, 0.00784313725490196, 0.4980392156862745),
#  (0.7490196078431373, 0.3568627450980392, 0.09019607843137253),
#  (0.4, 0.4, 0.4)]

# %%
c=sns.color_palette('RdPu')
c
# Out:
# [(0.9916493656286044, 0.8647289504036909, 0.8519492502883507),
#  (0.9859592464436755, 0.7293041138023837, 0.7404229142637447),
#  (0.9754555940023067, 0.5330257593233372, 0.6768935024990388),
#  (0.9094502114571319, 0.2894886582083814, 0.6086120722798923),
#  (0.735840061514802, 0.06196078431372548, 0.5225682429834679),
#  (0.5048212226066897, 0.00392156862745098, 0.47021914648212226)]

# %%
sns.color_palette('RdPu',2)
# Out:
# [(0.9830065359477124, 0.673202614379085, 0.7241830065359477),
#  (0.8052287581699347, 0.13725490196078433, 0.5594771241830065)]

# %%
sns.palplot(c)# -1 to 1

# %%
sns.palplot(c,size=0.5)

# %%
sns.cubehelix_palette()
# Out:
# [[0.9312692223325372, 0.8201921796082118, 0.7971480974663592],
#  [0.8559578605899612, 0.6418993116910497, 0.6754191211563135],
#  [0.739734329496642, 0.4765280683170713, 0.5959617419736206],
#  [0.57916573903086, 0.33934576125314425, 0.5219003947563425],
#  [0.37894937987024996, 0.2224702044652721, 0.41140014301575434],
#  [0.1750865648952205, 0.11840023306916837, 0.24215989137836502]]

# %%
sns.cubehelix_palette(3)
# Out:
# [[0.9312692223325372, 0.8201921796082118, 0.7971480974663592],
#  [0.6672565752652589, 0.40671838146419587, 0.5620016466433286],
#  [0.1750865648952205, 0.11840023306916837, 0.24215989137836502]]

# %%
sns.cubehelix_palette(n_colors=3,reverse=True)## it prints the color in reverse order
# Out:
# [[0.1750865648952205, 0.11840023306916837, 0.24215989137836502],
#  [0.6672565752652589, 0.40671838146419587, 0.5620016466433286],
#  [0.9312692223325372, 0.8201921796082118, 0.7971480974663592]]

# %%
sns.cubehelix_palette(n_colors=3,reverse=True,hue=2)
# Out:
# [[0.21418700047334538, 0.07247117090821505, 0.38187031668120663],
#  [0.9152002616925591, 0.26385477718990147, 0.6520629401377334],
#  [1.0, 0.7740098607852354, 0.716399655430604]]

# %%
sns.light_palette("red")
# Out:
# [(0.9522635075378764, 0.9411073728435433, 0.940983659029102),
#  (0.9618108060303011, 0.7528858982748347, 0.7527869272232816),
#  (0.9713581045227259, 0.564664423706126, 0.5645901954174611),
#  (0.9809054030151505, 0.3764429491374174, 0.37639346361164083),
#  (0.9904527015075753, 0.18822147456870864, 0.1881967318058203),
#  (1.0, 0.0, 0.0)]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# catplot
#help(sns.catplot)

# %%
sns.catplot(data=df)

# %%
sns.catplot(data=df,kind="box")

# %%
sns.catplot(x="species",y="sepal_length",data=df,hue="petal_width")

# %%
sns.catplot(x="petal_width",y="sepal_length",data=df,hue="species")

# %%
sns.catplot(x="species",y="sepal_length",data=df,hue="petal_width",kind="swarm")

# %%
sns.catplot(x="sepal_length",y="species",data=df,hue="petal_width",kind="swarm")

# %%
sns.catplot(x="petal_length",y="species",data=df,col="species",kind="box")

# %%
sns.catplot(x="petal_length",y="species",data=df,col="species",kind="violin")

# %%
sns.catplot(x="petal_length",y="petal_width",data=df,hue="species",palette=["r","g","b"])

# %%
sns.catplot(x="petal_length",y="petal_width",data=df,hue="species",palette=["r","g","b"],marker='*')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df1=sns.load_dataset("tips")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
##box plot
sns.boxplot(x="day",y="tip",data=df1)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day",y="tip",data=df1,hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(y="day",x="total_bill",data=df1,hue="smoker",width=0.7,orient="h")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.lineplot(x="day",y="total_bill",data=df1,hue="smoker")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="tip",data=df1,hue="sex")
sns.swarmplot(x="day",y="tip",data=df1,hue="sex",color="g")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# ## violinplot
# - boxplot and kdeplot
# - sns.violinplot()

# %%
sns.violinplot(x="day",y="tip",data=df1,hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df3=sns.load_dataset('dots')
df3
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue="choice")
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue="choice",palette=["g","b"])
sns.violinplot(x='align',y='firing_rate',data=df3,hue="choice",dodge=False)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue="choice",inner="quartile")
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue="choice",inner="stick")
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %% [markdown]
# ## kdeplot
# - kernal density estimate plot
#   - distributed data
# - sns.kdeplot()

# %%
df3
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.kdeplot(x="firing_rate",data=df3)
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.kdeplot(y="firing_rate",data=df3)
# Out:
# <AxesSubplot:xlabel='Density', ylabel='firing_rate'>

# %%
sns.set_style("darkgrid")
sns.kdeplot(y="firing_rate",data=df3)
sns.set_context("poster")

# %%
sns.set_style("darkgrid")
sns.kdeplot(y="firing_rate",data=df3)
sns.set_context("paper")

# %% [markdown]
# # jointplot
# - join the different plots together
# -sns.jointplot()

# %%
sns.jointplot(x="firing_rate",y="coherence",data=df3,hue="time")

# %%
sns.jointplot(x="firing_rate",y="coherence",data=df3,kind="reg")

# %%
sns.jointplot(x="firing_rate",y="coherence",data=df3,kind="hist")

# %%
sns.jointplot(x="firing_rate",y="coherence",data=df3,kind="hex")

# %%
sns.jointplot(x="firing_rate",y="coherence",data=df3,kind="resid")

# %% [markdown]
# ## pair plot
# - it displays a relationship between a features or data
# - sns.pairplot()

# %%
sns.pairplot(data=df3)# only for integer values

# %%
import pandas as pd

# %%
df3["choice"].value_counts()
# Out:
# T2    430
# T1    418
# Name: choice, dtype: int64

# %%
sns.pairplot(data=df3,hue="choice",markers=['o','*'])

# %% [markdown]
# ## count plot
# - sns.countplot()

# %%
sns.countplot(x="choice",data=df3,hue="align")
# Out:
# <AxesSubplot:xlabel='choice', ylabel='count'>

# %%
sns.countplot(x="firing_rate",data=df3,hue="align")

# %%
sns.barplot(x="firing_rate",y="choice",data=df3,hue="align")
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %%
import numpy as np

# %%
sns.barplot(x="firing_rate",y="choice",data=df3,hue="align",estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %% [markdown]
# ## correlation
# - Negatively correlate, 1-high correlated
# - df.head()
# - corr=df.corr()
# - corr

# %%
df.head()
corr=df.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## point plot

# %%
sns.pointplot(x="sepal_length",y="species",data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.pointplot(x="sepal_length",y="species",data=df,join=False)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>
